# %% [markdown]
# # Capitulo II — Origen del Proceso como Lente de SegmentacionCatalogo de preguntas que cruzan `origen_proceso` con otras dimensiones.

# %% [markdown]
# ## II.1 origen_proceso x experiencia_anios- [x] **[Promedio por Origen]** ¿Cual es la media de anos de experiencia para cada origen?- [x] **[Mediana por Origen]** ¿Cual es el valor central por origen?- [x] **[Moda por Origen]** ¿Cual es el valor mas frecuente por origen?- [x] **[Distribucion de Niveles]** ¿Como se reparten Junior/Middle/Senior en cada origen?- [x] **[Entry Level]** ¿Que porcentaje de ofertas no pide experiencia en cada origen?

# %% [markdown]
# ## II.2 origen_proceso x fecha_publicacion_estimada- [ ] **[Volumen por Dia]** ¿El patron de publicacion (lunes pico) se repite en cada origen?- [ ] **[Recencia por Origen]** ¿Hay origenes con ofertas mas frescas?- [ ] **[Fuga Fin de Semana]** ¿La caida del finde afecta igual a todos los origenes?

# %% [markdown]
# ## II.3 origen_proceso x empresa- [ ] **[Diversidad]** ¿Cuantas empresas distintas publican en cada origen?- [ ] **[Concentracion]** ¿Un origen concentra pocas empresas con muchas ofertas?- [ ] **[Top por Origen]** ¿El ranking de empresas cambia segun el origen?
