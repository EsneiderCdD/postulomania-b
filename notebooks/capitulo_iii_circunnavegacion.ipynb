# %% [markdown]
# # Capitulo III — Matriz Completa de CrucesCatalogo de todos los cruces entre dimensiones ejecutados en el proyecto.

# %% [markdown]
# ## Matriz final (filas = agrupar por, columnas = metrica calculada)| | origen | ingles | exp | empresa | techs | compat | fecha || --- | --- | --- | --- | --- | --- | --- | --- || **origen** | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ || **ingles** | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ || **experiencia** | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ || **empresa** | ✅ | ✅ | ✅ | ✅ | nv | ✅ | nv || **tech_stack** | ✅ | ✅ | ✅ | nv | ✅ | ✅ | nv || **compatibilidad** | ✅ | ✅ | ✅ | ✅ | ✅ | ✅ | nv || **fecha** | ✅ | ✅ | ✅ | nv | nv | nv | ✅ |nv = no viable con el volumen actual de datos (58 ofertas).

# %% [markdown]
# ## Endpoints del Capitulo III (nuevos cruces)- [x] `GET /origen-timing` — volumen por dia, dia pico y fuga finde por origen- [x] `GET /origen-empresa` — empresas unicas, top 3 y larga cola por origen- [x] `GET /english-timing` — volumen por dia, dia pico y fuga finde por ingles- [x] `GET /experience-empresa` — promedio de experiencia por empresa y nivel mas demandado- [x] `GET /experience-compatibility` — score promedio por nivel de experiencia y correlacion- [x] `GET /experience-timing` — experiencia promedio y mediana por dia de la semana- [x] `GET /empresa-compatibility` — top empresas por score y empresas con match cero- [x] `GET /tech-compatibility` — top y bottom tecnologias por score de compatibilidad

# %% [markdown]
# ## Cruces NO viables (y por que)- `empresa x fecha`: 44 empresas, la mayoria con 1 oferta → sin patron temporal- `empresa x techs`: misma razon, sin volumen no hay ranking significativo- `compatibilidad x fecha`: solo 37 dias de rango → sin tendencia real- `techs x fecha`: granularidad excesiva para 58 ofertasEstos cruces seran viables cuando el scraper acumule mas volumen de ofertas.

# %% [markdown]
# ## Resumen de endpoints totales**Capitulo I**: 8 endpoints (1 por tabla/base) + 1 extra (/id como auditoria)**Capitulo II**: 1 endpoint (origen-experience)**Capitulo III**: 8 endpoints (cruces entre dimensiones)**Total**: 17 endpoints en produccion.
