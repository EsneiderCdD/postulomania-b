# %% [markdown]
# # 🔮 PRESAGIO — Capitulo IIMatriz pedagogica de cruces ejecutados y pendientes.Fila = agrupar por. Columna = metrica calculada.| | origen | ingles | exp | empresa | techs | compat | fecha || --- | --- | --- | --- | --- | --- | --- | --- || **origen** | ✅ freq | ✅ conc | ✅ II.1 | ❌ II.3 | ✅ tend | ✅ perf | ❌ II.2 || **ingles** | ✅ conc | ✅ prop | ✅ | ✅ excl | ✅ top | ✅ imp | ❌ || **experiencia** | ✅ II.1 | ✅ imp | ✅ | ❌ | ✅ corr | ❌ | ❌ || **empresa** | ❌ II.3 | ✅ excl | ❌ | ✅ top | ❌ | ❌ | ❌ || **techs** | ✅ tend | ✅ top | ✅ | ❌ | ✅ pop | ❌ | ❌ || **compat** | ✅ perf | ✅ imp | ❌ | ❌ | ❌ | ✅ stats | ❌ || **fecha** | ❌ II.2 | ❌ | ❌ | ❌ | ❌ | ❌ | ✅ vol |✅ = ejecutado. ❌ = pendiente. II.X = ejecutado en este capitulo.### ReglaCada ❌ se transforma en un `groupby().mean()` o `groupby().value_counts()`.Cada ✅ puede tener su propio endpoint en la API y su componente en el frontend.
